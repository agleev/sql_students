# %%
import pandas as pd
import psycopg2
from config_postgresql import database, user, password, port, host

# %%
connection = psycopg2.connect(database=database, user = user, password=password, port=port, host=host)
connection.autocommit = True

# %%
def sql(request):
    cursor = connection.cursor()
    cursor.execute(request)
    result = cursor.fetchall()
    columns = []
    for desc in cursor.description:
        columns.append(desc[0])
    
    return pd.DataFrame(result, columns=columns)

# %%
sql('''SELECT 
    CONCAT(module_id, ' ', LEFT(CONCAT(module_name), 14), '...') AS Модуль,
    CONCAT(module_id, '.', lesson_position, ' ', LEFT(CONCAT(lesson_name), 12), '...') AS Урок,
    CONCAT(module_id, '.', lesson_position, '.', step_position, step_name) AS Шаг
FROM
    module
    INNER JOIN lesson USING(module_id)
    INNER JOIN step USING(lesson_id)
WHERE step_name LIKE '%вложен%запрос%'
ORDER BY Модуль, Урок, Шаг;''')
# Out:
#                 Модуль                 Урок  \
# 0  1 Основы реляцио...  1.4 Вложенные за...
# 1  1 Основы реляцио...  1.4 Вложенные за...
# 2  1 Основы реляцио...  1.5 Запросы корр...
# 3  1 Основы реляцио...  1.5 Запросы корр...
# 4  2 Запросы SQL к ...  2.2 Запросы на в...
# 5  2 Запросы SQL к ...  2.2 Запросы на в...
# 6  2 Запросы SQL к ...  2.3 Запросы корр...
# 7  2 Запросы SQL к ...  2.3 Запросы корр...
#
#                                                  Шаг
# 0  1.4.3Использование вложенного запроса в выражении
# 1  1.4.3Использование вложенного запроса в выражении
# 2         1.5.5Добавление записей, вложенные запросы
# 3         1.5.5Добавление записей, вложенные запросы
# 4  2.2.7Запросы для нескольких таблиц со вложенны...
# 5  2.2.7Запросы для нескольких таблиц со вложенны...
# 6       2.3.5Запрос на обновление, вложенные запросы
# 7       2.3.5Запрос на обновление, вложенные запросы

# %% [markdown]
# Вывести первых 10 `student_id` с самым большим числом правильных ответов.

# %%
sql('''select student_id, count(result) as Количество
from step_student
where result = 'correct'
group by student_id
order by Количество desc
limit 10''')
# Out:
#    student_id  Количество
# 0          53          68
# 1          60          66
# 2          36          62
# 3           9          62
# 4          46          62
# 5          30          62
# 6          39          62
# 7          15          62
# 8          59          60
# 9           4          60

# %%
sql('''


select * from lesson




''')
# Out:
#     lesson_id                                        lesson_name  module_id  \
# 0           1                                 Отношение(таблица)          1
# 1           2                                     Выборка данных          1
# 2           3         Таблица "Командировки", запросы на выборку          1
# 3           4                                  Вложенные запросы          1
# 4           5                        Запросы, групповые операции          1
# 5           6                       Запросы корректировки данных          1
# 6           7     Таблица "Нарушение ПДД", запросы корректировки          1
# 7           8                              Связи между таблицами          2
# 8           9              Запросы на выборку, соединение таблиц          2
# 9          10           Запросы корректировки, соединение таблиц          2
# 10         11  База данных "Интернет-магазин книг", запросы н...          2
# ...

# %%
sql('''


select student_name, sum((submission_time - attempt_time)) as sec from step_student

join student using(student_id)

where result = 'correct'

group by student_name

order by sec desc

''')
# Out:
#    student_name      sec
# 0    student_31  1916275
# 1     student_4  1087469
# 2    student_57   995521
# 3    student_43   688631
# 4    student_45   668937
# ..          ...      ...
# 59   student_18     1079
# 60   student_64      924
# 61    student_3      897
# 62    student_7      535
# 63   student_23      371
#
# [64 rows x 2 columns]

# %%
sql('''


select distinct step_id from step_student

order by 1

''')
# Out:
#     step_id
# 0        10
# 1        11
# 2        12
# 3        13
# 4        14
# 5        15
# 6        16
# 7        17
# 8        18
# 9        19
# 10       20
# 11       81
# 12       82
# 13       83
# 14       84
# 15       85
# 16       86
# 17       87
# 18       88
# 19      100
# 20      101
# 21      103
# 22      104
# 23      105
# 24      106
# 25      107
# 26      108
# 27      109
# 28      110
# 29      111
# 30      112
# 31      113

# %% [markdown]
# 2. Выведите топ-20 студентов по прогрессу в прохождении курса. В отдельных столбцах укажите, сколько у них было неправльных ответов, какое среднее время решения заданий и в % укажите, насколько полно освоен курс от общего числа заданий

# %%
sql('''
with correct_raiting (student_name, count_step) as

    (
        select student_name, count(distinct step_id) as count_step from step_student
        join student using(student_id)
        where result = 'correct'
        group by student_name
    ),

wrong_raiting (student_name, count_wrong) as

    (
        select student_name, count(result) as count_wrong from step_student
        join student using(student_id)
        where result = 'wrong'
        group by student_name    
    )

select student_name, 
(count_step*100/(select count(distinct step_id) from step_student)) as percent, wrong_raiting.count_wrong 
from correct_raiting
join wrong_raiting using(student_name)
''')
# Out:
#    student_name  percent  count_wrong
# 0     student_1       34           14
# 1    student_10       34           10
# 2    student_11       50            4
# 3    student_12       34           15
# 4    student_13       40            8
# 5    student_14       34            7
# 6    student_15       93           42
# 7    student_16       28           16
# 8    student_17       31            5
# 9    student_18       93           11
# 10   student_19       34            7
# 11   student_20       78            5
# 12   student_22       34           13
# 13   student_23       87           28
# 14   student_24       78          102
# 15   student_25       34            2
# 16   student_26       40            3
# 17   student_27       93           50
# 18   student_28       34            7
# 19   student_29       25            4
# 20    student_3       34           18
# 21   student_30       93            1
# 22   student_31       93            3
# 23   student_32       34            4
# ...

# %%
sql('''


select student_id, count(result) from step_student

where result = 'wrong'

group by student_id

order by count desc

''')
# Out:
#     student_id  count
# 0           43    140
# 1           36    105
# 2           24    102
# 3            9     70
# 4           27     50
# 5           40     47
# 6           15     42
# 7           51     42
# 8           50     36
# 9           64     35
# 10          61     29
# 11          59     28
# 12          23     28
# 13           3     18
# 14          16     16
# 15          12     15
# 16          52     14
# 17           1     14
# 18          57     13
# 19          22     13
# 20          53     13
# 21           7     13
# 22          34     11
# 23          18     11
# 24          10     10
# 25          62     10
# 26          37      9
# 27          49      9
# 28          60      9
# 29          39      9
# 30          55      8
# 31          13      8
# 32          58      7
# 33           6      7
# 34          14      7
# 35          19      7
# 36          28      7
# 37          33      7
# 38          42      6
# 39           4      6
# ...
